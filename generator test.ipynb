# %%
import string
import cv2
import matplotlib.pyplot as plt

# %%
characters = string.ascii_lowercase + string.ascii_uppercase
print(characters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
img = cv2.imread('sample/APKD.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img[:, 20:], cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img[:, 20:21], cv2.COLOR_BGR2RGB))
plt.show()

# %%
img[:, 20:22]
# Out:
# array([[[249, 240, 253],
#         [255, 250, 255]],
#
#        [[249, 242, 255],
#         [250, 243, 255]],
#
#        [[245, 244, 255],
#         [243, 240, 255]],
#
#        [[236, 240, 255],
#         [234, 236, 254]],
#
#        [[231, 242, 255],
#         [228, 238, 255]],
#
#        [[229, 250, 255],
#         [232, 251, 255]],
#
#        [[193, 223, 248],
#         [219, 246, 255]],
#
#        [[131, 171, 200],
#         [183, 220, 248]],
#
#        [[ 57, 106, 138],
#         [165, 212, 243]],
#
#        [[ 30,  90, 126],
#         [140, 196, 231]],
#
#        [[ 41, 110, 149],
#         [112, 177, 215]],
#
#        [[ 25, 104, 145],
#         [ 38, 113, 152]],
#
#        [[ 14,  99, 144],
#         [  0,  82, 123]],
#
#        [[ 23, 114, 159],
#         [  8,  95, 139]],
#
#        [[ 13, 109, 155],
#         [  0,  86, 131]],
#
#        [[ 28, 126, 174],
#         [  5,  98, 143]],
#
#        [[  5,  82, 144],
#         [ 17, 102, 170]],
#
#        [[ 25, 101, 160],
# ...

# %%
plt.imshow(cv2.cvtColor(img[10:11, 20:21], cv2.COLOR_BGR2RGB))
plt.show()

# %%
img[10:11, 20:21]
# Out:
# array([[[ 41, 110, 149]]], dtype=uint8)

# %%
img[0, 0]
# Out:
# array([243, 245, 255], dtype=uint8)

# %%
img[-1, -1]
# Out:
# array([237, 247, 254], dtype=uint8)

# %%
img[0]
# Out:
# array([[243, 245, 255],
#        [243, 245, 255],
#        [243, 245, 255],
#        [243, 245, 255],
#        [241, 246, 255],
#        [241, 247, 254],
#        [241, 247, 254],
#        [241, 247, 252],
#        [241, 247, 252],
#        [239, 248, 252],
#        [239, 248, 251],
#        [239, 248, 251],
#        [239, 248, 251],
#        [239, 249, 249],
#        [239, 249, 249],
#        [239, 249, 249],
#        [226, 252, 238],
#        [239, 255, 251],
#        [246, 255, 255],
#        [243, 242, 251],
#        [249, 240, 253],
#        [255, 250, 255],
#        [255, 253, 255],
#        [238, 247, 244],
#        [230, 253, 239],
#        [225, 255, 235],
#        [223, 255, 233],
#        [227, 254, 238],
#        [234, 248, 246],
#        [244, 242, 254],
#        [253, 236, 255],
#        [255, 233, 255],
#        [238, 252, 251],
#        [237, 251, 250],
#        [235, 249, 248],
#        [234, 248, 247],
#        [234, 248, 247],
#        [235, 249, 248],
# ...

# %%
img[-1]
# Out:
# array([[237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
# ...

# %%
print 'the orange background is [237, 247, 254]'
# Out:
# the orange background is [237, 247, 254]

# %%
img = cv2.imread('sample/ABGq.png')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img.shape
# Out:
# (53L, 130L, 3L)

# %%
img[-1]
# Out:
# array([[246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
# ...

# %%
print 'the orange background is [237, 247, 254]'
print 'the blue background is [246, 246, 246]'
# Out:
# the orange background is [237, 247, 254]
# the blue background is [246, 246, 246]

# %%
img = cv2.imread('sample/BAGA.png')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img[18:24, 58:64], cv2.COLOR_BGR2RGB))
plt.show()

# %%
img[18:24, 58:64]
# Out:
# array([[[ 81, 118,  46],
#         [ 80, 121,  36],
#         [ 85, 130,  33],
#         [ 79, 128,  18],
#         [ 66, 119,   0],
#         [ 82, 137,  10]],
#
#        [[ 84, 123,  45],
#         [ 74, 117,  26],
#         [ 95, 142,  40],
#         [ 78, 129,  15],
#         [ 70, 124,   1],
#         [ 86, 141,  14]],
#
#        [[ 77, 119,  32],
#         [ 57, 102,   5],
#         [ 89, 138,  30],
#         [ 71, 123,   5],
#         [ 68, 122,   0],
#         [ 77, 133,   4]],
#
#        [[ 81, 125,  30],
#         [ 60, 107,   4],
#         [ 88, 138,  26],
#         [ 74, 127,   6],
#         [ 76, 131,   4],
#         [ 76, 133,   1]],
#
#        [[ 90, 137,  34],
#         [ 76, 125,  15],
#         [ 90, 142,  25],
#         [ 77, 131,   8],
#         [ 83, 138,  11],
#         [ 75, 132,   0]],
#
#        [[ 87, 136,  26],
#         [ 80, 132,  15],
#         [ 82, 135,  14],
#         [ 67, 121,   0],
#         [ 76, 131,   4],
# ...

# %%
img[-1]
# Out:
# array([[237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
# ...

# %%
print 'the orange background is [237, 247, 254]'
print 'the blue background is [246, 246, 246]'
print 'the green background is [237, 247, 254]'
# Out:
# the orange background is [237, 247, 254]
# the blue background is [246, 246, 246]
# the green background is [237, 247, 254]

# %%
img = cv2.imread('sample/BACT.png')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img[18:22, 99:102], cv2.COLOR_BGR2RGB))
plt.show()

# %%
img[18:22, 99:102]
# Out:
# array([[[174,  35,   0],
#         [214,  65,   8],
#         [201,  53,   0]],
#
#        [[209,  56,  11],
#         [232,  74,  26],
#         [212,  61,  16]],
#
#        [[243,  77,  40],
#         [228,  64,  22],
#         [207,  54,  15]],
#
#        [[226,  54,  18],
#         [203,  34,   0],
#         [194,  39,   0]]], dtype=uint8)

# %%
img[-1]
# Out:
# array([[246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
# ...

# %%
img = cv2.imread('sample/CRLF.png')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img[18:22, 68:71], cv2.COLOR_BGR2RGB))
plt.show()

# %%
img[18:22, 68:71]
# Out:
# array([[[ 40, 108, 153],
#         [ 40, 108, 151],
#         [ 44, 105, 139]],
#
#        [[ 39, 111, 159],
#         [ 37, 108, 152],
#         [ 43, 106, 144]],
#
#        [[ 42, 115, 167],
#         [ 36, 108, 156],
#         [ 35, 101, 142]],
#
#        [[ 40, 114, 168],
#         [ 31, 106, 158],
#         [ 30,  98, 143]]], dtype=uint8)

# %%
img[-1]
# Out:
# array([[237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
#        [237, 247, 254],
# ...

# %%
img = cv2.imread('img_data/all/448.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
img = cv2.imread('img_data/all/424.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
img = cv2.imread('img_data/all/435.jpg')

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(img)
plt.show()

# %%
img[10:20, 70:80]
# Out:
# array([[[172, 129,  50],
#         [156, 116,  34],
#         [163, 123,  41],
#         [162, 123,  45],
#         [150, 113,  39],
#         [144, 110,  40],
#         [153, 121,  56],
#         [150, 121,  60],
#         [145, 116,  59],
#         [145, 118,  61]],
#
#        [[168, 126,  49],
#         [158, 117,  38],
#         [164, 123,  44],
#         [162, 124,  46],
#         [149, 112,  38],
#         [142, 107,  39],
#         [152, 120,  55],
#         [152, 122,  63],
#         [145, 116,  59],
#         [143, 116,  60]],
#
#        [[162, 122,  47],
#         [168, 127,  48],
#         [164, 123,  44],
#         [166, 124,  47],
#         [153, 113,  38],
#         [144, 106,  34],
#         [152, 117,  49],
#         [158, 123,  59],
#         [150, 116,  56],
#         [146, 114,  55]],
#
#        [[155, 114,  41],
#         [166, 122,  45],
#         [167, 122,  41],
#         [171, 126,  45],
#         [161, 115,  37],
#         [150, 106,  29],
# ...

# %%
def show(img):
    img = cv2.imread('img_data/all/%d.jpg' %img)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()

# %%
show(332)

# %%
img = cv2.imread('img_data/all/%d.jpg' %(332))

# %%
cv2.imshow("Image", img)   
cv2.waitKey (0)  
cv2.destroyAllWindows()

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.imshow(cv2.cvtColor(img[10:40, 90:95], cv2.COLOR_BGR2RGB))
plt.show()

# %%
img[-1]
# Out:
# array([[246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [246, 246, 246],
#        [250, 246, 245],
#        [250, 246, 245],
#        [248, 246, 245],
#        [248, 246, 246],
#        [250, 245, 246],
#        [250, 245, 246],
#        [250, 245, 246],
#        [251, 245, 246],
#        [255, 248, 250],
#        [234, 222, 222],
#        [236, 221, 218],
#        [218, 199, 194],
#        [209, 187, 181],
#        [185, 162, 154],
#        [154, 129, 119],
#        [163, 136, 126],
#        [157, 140, 127],
#        [235, 165, 158],
#        [173,  48,  44],
#        [212,  70,  63],
#        [231, 118, 102],
#        [235, 162, 140],
# ...

# %%
show(871)
